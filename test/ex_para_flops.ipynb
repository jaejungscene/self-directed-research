# %%
from torchsummary import summary
import torch 
model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet50', pretrained=False)
summary(model, (3,224,224))
# Out:
# Using cache found in /home/ljj0512/.cache/torch/hub/pytorch_vision_v0.10.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/ljj0512/private/project/test/ex_para_flops.ipynb Cell 1 in <cell line: 4>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bcilab1.ajou.ac.kr/home/ljj0512/private/project/test/ex_para_flops.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import torch
#       <a href='vscode-notebook-cell://ssh-remote%2Bcilab1.ajou.ac.kr/home/ljj0512/private/project/test/ex_para_flops.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet50', pretrained=False)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcilab1.ajou.ac.kr/home/ljj0512/private/project/test/ex_para_flops.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> summary(model)
#
# TypeError: summary() missing 1 required positional argument: 'input_size'

# %%
import torch 
model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet50', pretrained=False)
print('the number of model parameters: {}'.format(sum([p.data.nelement() for p in model.parameters()])))
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.10.0" to /home/ljj0512/.cache/torch/hub/v0.10.0.zip
# the number of model parameters: 25557032

# %%
import torchvision.models as models
import torch
from ptflops import get_model_complexity_info

model = models.densenet161()
macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# Warning: module _DenseLayer is treated as a zero-op.
# Warning: module _DenseBlock is treated as a zero-op.
# Warning: module _Transition is treated as a zero-op.
# Warning: module DenseNet is treated as a zero-op.
# DenseNet(
#   28.68 M, 100.000% Params, 7.82 GMac, 100.000% MACs,
#   (features): Sequential(
#     26.47 M, 92.298% Params, 7.82 GMac, 99.972% MACs,
#     (conv0): Conv2d(14.11 k, 0.049% Params, 177.02 MMac, 2.264% MACs, 3, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(192, 0.001% Params, 2.41 MMac, 0.031% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(0, 0.000% Params, 1.2 MMac, 0.015% MACs, inplace=True)
#     (pool0): MaxPool2d(0, 0.000% Params, 1.2 MMac, 0.015% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       751.39 k, 2.620% Params, 2.36 GMac, 30.237% MACs,
#       (denselayer1): _DenseLayer(
#         101.95 k, 0.355% Params, 320.62 MMac, 4.101% MACs,
#         (norm1): BatchNorm2d(192, 0.001% Params, 602.11 KMac, 0.008% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 301.06 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(18.43 k, 0.064% Params, 57.8 MMac, 0.739% MACs, 96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.015% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 602.11 KMac, 0.008% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 260.11 MMac, 3.327% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         111.26 k, 0.388% Params, 349.98 MMac, 4.476% MACs,
#         (norm1): BatchNorm2d(288, 0.001% Params, 903.17 KMac, 0.012% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 451.58 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(27.65 k, 0.096% Params, 86.7 MMac, 1.109% MACs, 144, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.015% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 602.11 KMac, 0.008% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 260.11 MMac, 3.327% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         120.58 k, 0.420% Params, 379.33 MMac, 4.852% MACs,
#         (norm1): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.015% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 602.11 KMac, 0.008% MACs, inplace=True)
#         (conv1): Conv2d(36.86 k, 0.129% Params, 115.61 MMac, 1.479% MACs, 192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.015% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 602.11 KMac, 0.008% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 260.11 MMac, 3.327% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         129.89 k, 0.453% Params, 408.68 MMac, 5.227% MACs,
#         (norm1): BatchNorm2d(480, 0.002% Params, 1.51 MMac, 0.019% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 752.64 KMac, 0.010% MACs, inplace=True)
#         (conv1): Conv2d(46.08 k, 0.161% Params, 144.51 MMac, 1.848% MACs, 240, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.015% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 602.11 KMac, 0.008% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 260.11 MMac, 3.327% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         139.2 k, 0.485% Params, 438.04 MMac, 5.603% MACs,
#         (norm1): BatchNorm2d(576, 0.002% Params, 1.81 MMac, 0.023% MACs, 288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 903.17 KMac, 0.012% MACs, inplace=True)
#         (conv1): Conv2d(55.3 k, 0.193% Params, 173.41 MMac, 2.218% MACs, 288, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.015% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 602.11 KMac, 0.008% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 260.11 MMac, 3.327% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         148.51 k, 0.518% Params, 467.39 MMac, 5.978% MACs,
#         (norm1): BatchNorm2d(672, 0.002% Params, 2.11 MMac, 0.027% MACs, 336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 1.05 MMac, 0.013% MACs, inplace=True)
#         (conv1): Conv2d(64.51 k, 0.225% Params, 202.31 MMac, 2.588% MACs, 336, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.015% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 602.11 KMac, 0.008% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 260.11 MMac, 3.327% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       74.5 k, 0.260% Params, 235.43 MMac, 3.011% MACs,
#       (norm): BatchNorm2d(768, 0.003% Params, 2.41 MMac, 0.031% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 1.2 MMac, 0.015% MACs, inplace=True)
#       (conv): Conv2d(73.73 k, 0.257% Params, 231.21 MMac, 2.957% MACs, 384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(0, 0.000% Params, 602.11 KMac, 0.008% MACs, kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       2.06 M, 7.188% Params, 1.62 GMac, 20.750% MACs,
#       (denselayer1): _DenseLayer(
#         120.58 k, 0.420% Params, 94.83 MMac, 1.213% MACs,
#         (norm1): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(36.86 k, 0.129% Params, 28.9 MMac, 0.370% MACs, 192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         129.89 k, 0.453% Params, 102.17 MMac, 1.307% MACs,
#         (norm1): BatchNorm2d(480, 0.002% Params, 376.32 KMac, 0.005% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 188.16 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(46.08 k, 0.161% Params, 36.13 MMac, 0.462% MACs, 240, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         139.2 k, 0.485% Params, 109.51 MMac, 1.401% MACs,
#         (norm1): BatchNorm2d(576, 0.002% Params, 451.58 KMac, 0.006% MACs, 288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 225.79 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(55.3 k, 0.193% Params, 43.35 MMac, 0.554% MACs, 288, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         148.51 k, 0.518% Params, 116.85 MMac, 1.495% MACs,
#         (norm1): BatchNorm2d(672, 0.002% Params, 526.85 KMac, 0.007% MACs, 336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 263.42 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(64.51 k, 0.225% Params, 50.58 MMac, 0.647% MACs, 336, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         157.82 k, 0.550% Params, 124.19 MMac, 1.588% MACs,
#         (norm1): BatchNorm2d(768, 0.003% Params, 602.11 KMac, 0.008% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 301.06 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(73.73 k, 0.257% Params, 57.8 MMac, 0.739% MACs, 384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         167.14 k, 0.583% Params, 131.52 MMac, 1.682% MACs,
#         (norm1): BatchNorm2d(864, 0.003% Params, 677.38 KMac, 0.009% MACs, 432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 338.69 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 432, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         176.45 k, 0.615% Params, 138.86 MMac, 1.776% MACs,
#         (norm1): BatchNorm2d(960, 0.003% Params, 752.64 KMac, 0.010% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 376.32 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(92.16 k, 0.321% Params, 72.25 MMac, 0.924% MACs, 480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         185.76 k, 0.648% Params, 146.2 MMac, 1.870% MACs,
#         (norm1): BatchNorm2d(1.06 k, 0.004% Params, 827.9 KMac, 0.011% MACs, 528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 413.95 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(101.38 k, 0.353% Params, 79.48 MMac, 1.017% MACs, 528, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         195.07 k, 0.680% Params, 153.54 MMac, 1.964% MACs,
#         (norm1): BatchNorm2d(1.15 k, 0.004% Params, 903.17 KMac, 0.012% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 451.58 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(110.59 k, 0.386% Params, 86.7 MMac, 1.109% MACs, 576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         204.38 k, 0.713% Params, 160.88 MMac, 2.058% MACs,
#         (norm1): BatchNorm2d(1.25 k, 0.004% Params, 978.43 KMac, 0.013% MACs, 624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 489.22 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(119.81 k, 0.418% Params, 93.93 MMac, 1.201% MACs, 624, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         213.7 k, 0.745% Params, 168.22 MMac, 2.152% MACs,
#         (norm1): BatchNorm2d(1.34 k, 0.005% Params, 1.05 MMac, 0.013% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 526.85 KMac, 0.007% MACs, inplace=True)
#         (conv1): Conv2d(129.02 k, 0.450% Params, 101.15 MMac, 1.294% MACs, 672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         223.01 k, 0.778% Params, 175.55 MMac, 2.245% MACs,
#         (norm1): BatchNorm2d(1.44 k, 0.005% Params, 1.13 MMac, 0.014% MACs, 720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 564.48 KMac, 0.007% MACs, inplace=True)
#         (conv1): Conv2d(138.24 k, 0.482% Params, 108.38 MMac, 1.386% MACs, 720, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.004% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 65.03 MMac, 0.832% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       296.45 k, 1.034% Params, 233.32 MMac, 2.984% MACs,
#       (norm): BatchNorm2d(1.54 k, 0.005% Params, 1.2 MMac, 0.015% MACs, 768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 602.11 KMac, 0.008% MACs, inplace=True)
#       (conv): Conv2d(294.91 k, 1.028% Params, 231.21 MMac, 2.957% MACs, 768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(0, 0.000% Params, 301.06 KMac, 0.004% MACs, kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       11.55 M, 40.264% Params, 2.27 GMac, 29.078% MACs,
#       (denselayer1): _DenseLayer(
#         157.82 k, 0.550% Params, 31.05 MMac, 0.397% MACs,
#         (norm1): BatchNorm2d(768, 0.003% Params, 150.53 KMac, 0.002% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 75.26 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(73.73 k, 0.257% Params, 14.45 MMac, 0.185% MACs, 384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         167.14 k, 0.583% Params, 32.88 MMac, 0.421% MACs,
#         (norm1): BatchNorm2d(864, 0.003% Params, 169.34 KMac, 0.002% MACs, 432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 84.67 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 432, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         176.45 k, 0.615% Params, 34.72 MMac, 0.444% MACs,
#         (norm1): BatchNorm2d(960, 0.003% Params, 188.16 KMac, 0.002% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 94.08 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(92.16 k, 0.321% Params, 18.06 MMac, 0.231% MACs, 480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         185.76 k, 0.648% Params, 36.55 MMac, 0.467% MACs,
#         (norm1): BatchNorm2d(1.06 k, 0.004% Params, 206.98 KMac, 0.003% MACs, 528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 103.49 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(101.38 k, 0.353% Params, 19.87 MMac, 0.254% MACs, 528, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         195.07 k, 0.680% Params, 38.38 MMac, 0.491% MACs,
#         (norm1): BatchNorm2d(1.15 k, 0.004% Params, 225.79 KMac, 0.003% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 112.9 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(110.59 k, 0.386% Params, 21.68 MMac, 0.277% MACs, 576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         204.38 k, 0.713% Params, 40.22 MMac, 0.514% MACs,
#         (norm1): BatchNorm2d(1.25 k, 0.004% Params, 244.61 KMac, 0.003% MACs, 624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 122.3 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(119.81 k, 0.418% Params, 23.48 MMac, 0.300% MACs, 624, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         213.7 k, 0.745% Params, 42.05 MMac, 0.538% MACs,
#         (norm1): BatchNorm2d(1.34 k, 0.005% Params, 263.42 KMac, 0.003% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 131.71 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(129.02 k, 0.450% Params, 25.29 MMac, 0.323% MACs, 672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         223.01 k, 0.778% Params, 43.89 MMac, 0.561% MACs,
#         (norm1): BatchNorm2d(1.44 k, 0.005% Params, 282.24 KMac, 0.004% MACs, 720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 141.12 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(138.24 k, 0.482% Params, 27.1 MMac, 0.347% MACs, 720, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         232.32 k, 0.810% Params, 45.72 MMac, 0.585% MACs,
#         (norm1): BatchNorm2d(1.54 k, 0.005% Params, 301.06 KMac, 0.004% MACs, 768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(147.46 k, 0.514% Params, 28.9 MMac, 0.370% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         241.63 k, 0.842% Params, 47.56 MMac, 0.608% MACs,
#         (norm1): BatchNorm2d(1.63 k, 0.006% Params, 319.87 KMac, 0.004% MACs, 816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 159.94 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(156.67 k, 0.546% Params, 30.71 MMac, 0.393% MACs, 816, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         250.94 k, 0.875% Params, 49.39 MMac, 0.632% MACs,
#         (norm1): BatchNorm2d(1.73 k, 0.006% Params, 338.69 KMac, 0.004% MACs, 864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 169.34 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(165.89 k, 0.578% Params, 32.51 MMac, 0.416% MACs, 864, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         260.26 k, 0.907% Params, 51.23 MMac, 0.655% MACs,
#         (norm1): BatchNorm2d(1.82 k, 0.006% Params, 357.5 KMac, 0.005% MACs, 912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 178.75 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(175.1 k, 0.611% Params, 34.32 MMac, 0.439% MACs, 912, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         269.57 k, 0.940% Params, 53.06 MMac, 0.679% MACs,
#         (norm1): BatchNorm2d(1.92 k, 0.007% Params, 376.32 KMac, 0.005% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 188.16 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(184.32 k, 0.643% Params, 36.13 MMac, 0.462% MACs, 960, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         278.88 k, 0.972% Params, 54.9 MMac, 0.702% MACs,
#         (norm1): BatchNorm2d(2.02 k, 0.007% Params, 395.14 KMac, 0.005% MACs, 1008, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 197.57 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(193.54 k, 0.675% Params, 37.93 MMac, 0.485% MACs, 1008, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         288.19 k, 1.005% Params, 56.73 MMac, 0.726% MACs,
#         (norm1): BatchNorm2d(2.11 k, 0.007% Params, 413.95 KMac, 0.005% MACs, 1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 206.98 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(202.75 k, 0.707% Params, 39.74 MMac, 0.508% MACs, 1056, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         297.5 k, 1.037% Params, 58.56 MMac, 0.749% MACs,
#         (norm1): BatchNorm2d(2.21 k, 0.008% Params, 432.77 KMac, 0.006% MACs, 1104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 216.38 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(211.97 k, 0.739% Params, 41.55 MMac, 0.531% MACs, 1104, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         306.82 k, 1.070% Params, 60.4 MMac, 0.773% MACs,
#         (norm1): BatchNorm2d(2.3 k, 0.008% Params, 451.58 KMac, 0.006% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 225.79 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(221.18 k, 0.771% Params, 43.35 MMac, 0.554% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         316.13 k, 1.102% Params, 62.23 MMac, 0.796% MACs,
#         (norm1): BatchNorm2d(2.4 k, 0.008% Params, 470.4 KMac, 0.006% MACs, 1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 235.2 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(230.4 k, 0.803% Params, 45.16 MMac, 0.578% MACs, 1200, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         325.44 k, 1.135% Params, 64.07 MMac, 0.819% MACs,
#         (norm1): BatchNorm2d(2.5 k, 0.009% Params, 489.22 KMac, 0.006% MACs, 1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 244.61 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(239.62 k, 0.835% Params, 46.96 MMac, 0.601% MACs, 1248, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         334.75 k, 1.167% Params, 65.9 MMac, 0.843% MACs,
#         (norm1): BatchNorm2d(2.59 k, 0.009% Params, 508.03 KMac, 0.006% MACs, 1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 254.02 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(248.83 k, 0.868% Params, 48.77 MMac, 0.624% MACs, 1296, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         344.06 k, 1.200% Params, 67.74 MMac, 0.866% MACs,
#         (norm1): BatchNorm2d(2.69 k, 0.009% Params, 526.85 KMac, 0.007% MACs, 1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 263.42 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(258.05 k, 0.900% Params, 50.58 MMac, 0.647% MACs, 1344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         353.38 k, 1.232% Params, 69.57 MMac, 0.890% MACs,
#         (norm1): BatchNorm2d(2.78 k, 0.010% Params, 545.66 KMac, 0.007% MACs, 1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 272.83 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(267.26 k, 0.932% Params, 52.38 MMac, 0.670% MACs, 1392, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         362.69 k, 1.265% Params, 71.41 MMac, 0.913% MACs,
#         (norm1): BatchNorm2d(2.88 k, 0.010% Params, 564.48 KMac, 0.007% MACs, 1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 282.24 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(276.48 k, 0.964% Params, 54.19 MMac, 0.693% MACs, 1440, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         372.0 k, 1.297% Params, 73.24 MMac, 0.937% MACs,
#         (norm1): BatchNorm2d(2.98 k, 0.010% Params, 583.3 KMac, 0.007% MACs, 1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 291.65 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(285.7 k, 0.996% Params, 56.0 MMac, 0.716% MACs, 1488, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         381.31 k, 1.329% Params, 75.08 MMac, 0.960% MACs,
#         (norm1): BatchNorm2d(3.07 k, 0.011% Params, 602.11 KMac, 0.008% MACs, 1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 301.06 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(294.91 k, 1.028% Params, 57.8 MMac, 0.739% MACs, 1536, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         390.62 k, 1.362% Params, 76.91 MMac, 0.984% MACs,
#         (norm1): BatchNorm2d(3.17 k, 0.011% Params, 620.93 KMac, 0.008% MACs, 1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 310.46 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(304.13 k, 1.060% Params, 59.61 MMac, 0.762% MACs, 1584, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         399.94 k, 1.394% Params, 78.74 MMac, 1.007% MACs,
#         (norm1): BatchNorm2d(3.26 k, 0.011% Params, 639.74 KMac, 0.008% MACs, 1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 319.87 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(313.34 k, 1.093% Params, 61.42 MMac, 0.786% MACs, 1632, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         409.25 k, 1.427% Params, 80.58 MMac, 1.031% MACs,
#         (norm1): BatchNorm2d(3.36 k, 0.012% Params, 658.56 KMac, 0.008% MACs, 1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 329.28 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(322.56 k, 1.125% Params, 63.22 MMac, 0.809% MACs, 1680, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         418.56 k, 1.459% Params, 82.41 MMac, 1.054% MACs,
#         (norm1): BatchNorm2d(3.46 k, 0.012% Params, 677.38 KMac, 0.009% MACs, 1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 338.69 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(331.78 k, 1.157% Params, 65.03 MMac, 0.832% MACs, 1728, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         427.87 k, 1.492% Params, 84.25 MMac, 1.078% MACs,
#         (norm1): BatchNorm2d(3.55 k, 0.012% Params, 696.19 KMac, 0.009% MACs, 1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 348.1 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(340.99 k, 1.189% Params, 66.83 MMac, 0.855% MACs, 1776, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         437.18 k, 1.524% Params, 86.08 MMac, 1.101% MACs,
#         (norm1): BatchNorm2d(3.65 k, 0.013% Params, 715.01 KMac, 0.009% MACs, 1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 357.5 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(350.21 k, 1.221% Params, 68.64 MMac, 0.878% MACs, 1824, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         446.5 k, 1.557% Params, 87.92 MMac, 1.125% MACs,
#         (norm1): BatchNorm2d(3.74 k, 0.013% Params, 733.82 KMac, 0.009% MACs, 1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 366.91 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(359.42 k, 1.253% Params, 70.45 MMac, 0.901% MACs, 1872, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer33): _DenseLayer(
#         455.81 k, 1.589% Params, 89.75 MMac, 1.148% MACs,
#         (norm1): BatchNorm2d(3.84 k, 0.013% Params, 752.64 KMac, 0.010% MACs, 1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 376.32 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(368.64 k, 1.285% Params, 72.25 MMac, 0.924% MACs, 1920, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer34): _DenseLayer(
#         465.12 k, 1.622% Params, 91.59 MMac, 1.171% MACs,
#         (norm1): BatchNorm2d(3.94 k, 0.014% Params, 771.46 KMac, 0.010% MACs, 1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 385.73 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(377.86 k, 1.317% Params, 74.06 MMac, 0.947% MACs, 1968, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer35): _DenseLayer(
#         474.43 k, 1.654% Params, 93.42 MMac, 1.195% MACs,
#         (norm1): BatchNorm2d(4.03 k, 0.014% Params, 790.27 KMac, 0.010% MACs, 2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 395.14 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(387.07 k, 1.350% Params, 75.87 MMac, 0.970% MACs, 2016, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer36): _DenseLayer(
#         483.74 k, 1.687% Params, 95.26 MMac, 1.218% MACs,
#         (norm1): BatchNorm2d(4.13 k, 0.014% Params, 809.09 KMac, 0.010% MACs, 2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 404.54 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(396.29 k, 1.382% Params, 77.67 MMac, 0.993% MACs, 2064, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 75.26 KMac, 0.001% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 37.63 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 16.26 MMac, 0.208% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       2.23 M, 7.791% Params, 438.58 MMac, 5.610% MACs,
#       (norm): BatchNorm2d(4.22 k, 0.015% Params, 827.9 KMac, 0.011% MACs, 2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 413.95 KMac, 0.005% MACs, inplace=True)
#       (conv): Conv2d(2.23 M, 7.776% Params, 437.13 MMac, 5.591% MACs, 2112, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(0, 0.000% Params, 206.98 KMac, 0.003% MACs, kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       9.49 M, 33.077% Params, 466.97 MMac, 5.973% MACs,
#       (denselayer1): _DenseLayer(
#         288.19 k, 1.005% Params, 14.18 MMac, 0.181% MACs,
#         (norm1): BatchNorm2d(2.11 k, 0.007% Params, 103.49 KMac, 0.001% MACs, 1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 51.74 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(202.75 k, 0.707% Params, 9.93 MMac, 0.127% MACs, 1056, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...
#         (norm1): BatchNorm2d(2.59 k, 0.009% Params, 127.01 KMac, 0.002% MACs, 1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 63.5 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(248.83 k, 0.868% Params, 12.19 MMac, 0.156% MACs, 1296, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         344.06 k, 1.200% Params, 16.93 MMac, 0.217% MACs,
#         (norm1): BatchNorm2d(2.69 k, 0.009% Params, 131.71 KMac, 0.002% MACs, 1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 65.86 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(258.05 k, 0.900% Params, 12.64 MMac, 0.162% MACs, 1344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         353.38 k, 1.232% Params, 17.39 MMac, 0.222% MACs,
#         (norm1): BatchNorm2d(2.78 k, 0.010% Params, 136.42 KMac, 0.002% MACs, 1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 68.21 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(267.26 k, 0.932% Params, 13.1 MMac, 0.168% MACs, 1392, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         362.69 k, 1.265% Params, 17.85 MMac, 0.228% MACs,
#         (norm1): BatchNorm2d(2.88 k, 0.010% Params, 141.12 KMac, 0.002% MACs, 1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 70.56 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(276.48 k, 0.964% Params, 13.55 MMac, 0.173% MACs, 1440, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         372.0 k, 1.297% Params, 18.31 MMac, 0.234% MACs,
#         (norm1): BatchNorm2d(2.98 k, 0.010% Params, 145.82 KMac, 0.002% MACs, 1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 72.91 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(285.7 k, 0.996% Params, 14.0 MMac, 0.179% MACs, 1488, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         381.31 k, 1.329% Params, 18.77 MMac, 0.240% MACs,
#         (norm1): BatchNorm2d(3.07 k, 0.011% Params, 150.53 KMac, 0.002% MACs, 1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 75.26 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(294.91 k, 1.028% Params, 14.45 MMac, 0.185% MACs, 1536, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         390.62 k, 1.362% Params, 19.23 MMac, 0.246% MACs,
#         (norm1): BatchNorm2d(3.17 k, 0.011% Params, 155.23 KMac, 0.002% MACs, 1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 77.62 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(304.13 k, 1.060% Params, 14.9 MMac, 0.191% MACs, 1584, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         399.94 k, 1.394% Params, 19.69 MMac, 0.252% MACs,
#         (norm1): BatchNorm2d(3.26 k, 0.011% Params, 159.94 KMac, 0.002% MACs, 1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 79.97 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(313.34 k, 1.093% Params, 15.35 MMac, 0.196% MACs, 1632, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         409.25 k, 1.427% Params, 20.14 MMac, 0.258% MACs,
#         (norm1): BatchNorm2d(3.36 k, 0.012% Params, 164.64 KMac, 0.002% MACs, 1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 82.32 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(322.56 k, 1.125% Params, 15.81 MMac, 0.202% MACs, 1680, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         418.56 k, 1.459% Params, 20.6 MMac, 0.264% MACs,
#         (norm1): BatchNorm2d(3.46 k, 0.012% Params, 169.34 KMac, 0.002% MACs, 1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 84.67 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(331.78 k, 1.157% Params, 16.26 MMac, 0.208% MACs, 1728, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         427.87 k, 1.492% Params, 21.06 MMac, 0.269% MACs,
#         (norm1): BatchNorm2d(3.55 k, 0.012% Params, 174.05 KMac, 0.002% MACs, 1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 87.02 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(340.99 k, 1.189% Params, 16.71 MMac, 0.214% MACs, 1776, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         437.18 k, 1.524% Params, 21.52 MMac, 0.275% MACs,
#         (norm1): BatchNorm2d(3.65 k, 0.013% Params, 178.75 KMac, 0.002% MACs, 1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 89.38 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(350.21 k, 1.221% Params, 17.16 MMac, 0.219% MACs, 1824, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         446.5 k, 1.557% Params, 21.98 MMac, 0.281% MACs,
#         (norm1): BatchNorm2d(3.74 k, 0.013% Params, 183.46 KMac, 0.002% MACs, 1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 91.73 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(359.42 k, 1.253% Params, 17.61 MMac, 0.225% MACs, 1872, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         455.81 k, 1.589% Params, 22.44 MMac, 0.287% MACs,
#         (norm1): BatchNorm2d(3.84 k, 0.013% Params, 188.16 KMac, 0.002% MACs, 1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 94.08 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(368.64 k, 1.285% Params, 18.06 MMac, 0.231% MACs, 1920, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         465.12 k, 1.622% Params, 22.9 MMac, 0.293% MACs,
#         (norm1): BatchNorm2d(3.94 k, 0.014% Params, 192.86 KMac, 0.002% MACs, 1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 96.43 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(377.86 k, 1.317% Params, 18.51 MMac, 0.237% MACs, 1968, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         474.43 k, 1.654% Params, 23.36 MMac, 0.299% MACs,
#         (norm1): BatchNorm2d(4.03 k, 0.014% Params, 197.57 KMac, 0.003% MACs, 2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 98.78 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(387.07 k, 1.350% Params, 18.97 MMac, 0.243% MACs, 2016, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         483.74 k, 1.687% Params, 23.81 MMac, 0.305% MACs,
#         (norm1): BatchNorm2d(4.13 k, 0.014% Params, 202.27 KMac, 0.003% MACs, 2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 101.14 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(396.29 k, 1.382% Params, 19.42 MMac, 0.248% MACs, 2064, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         493.06 k, 1.719% Params, 24.27 MMac, 0.310% MACs,
#         (norm1): BatchNorm2d(4.22 k, 0.015% Params, 206.98 KMac, 0.003% MACs, 2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 103.49 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(405.5 k, 1.414% Params, 19.87 MMac, 0.254% MACs, 2112, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         502.37 k, 1.752% Params, 24.73 MMac, 0.316% MACs,
#         (norm1): BatchNorm2d(4.32 k, 0.015% Params, 211.68 KMac, 0.003% MACs, 2160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 105.84 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(414.72 k, 1.446% Params, 20.32 MMac, 0.260% MACs, 2160, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(384, 0.001% Params, 18.82 KMac, 0.000% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 9.41 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(82.94 k, 0.289% Params, 4.06 MMac, 0.052% MACs, 192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(4.42 k, 0.015% Params, 216.38 KMac, 0.003% MACs, 2208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(2.21 M, 7.702% Params, 2.21 MMac, 0.028% MACs, in_features=2208, out_features=1000, bias=True)
# )
# Computational complexity:       7.82 GMac
# Number of parameters:           28.68 M

# %%
import torch
import torchvision.models as models

from pthflops import count_ops

# Create a network and a corresponding input
# device = 'cuda:0'
model = models.resnet18()
# model = models.densenet161()
inp = torch.rand(128,3,224,224)

# Count the number of FLOPs
count_ops(model, inp)
# Out:
# Operation               OPS
# ----------------------  ------------
# conv1                   15105785856
# bn1                     205520896
# relu                    205520896
# maxpool                 205520896
# layer1_0_conv1          14797504512
# layer1_0_bn1            51380224
# layer1_0_relu           51380224
# layer1_0_conv2          14797504512
# layer1_0_bn2            51380224
# add                     51380224
# layer1_0_relu_1         51380224
# layer1_1_conv1          14797504512
# layer1_1_bn1            51380224
# layer1_1_relu           51380224
# layer1_1_conv2          14797504512
# layer1_1_bn2            51380224
# add_1                   51380224
# layer1_1_relu_1         51380224
# layer2_0_conv1          7398752256
# layer2_0_bn1            25690112
# layer2_0_relu           25690112
# layer2_0_conv2          14797504512
# layer2_0_bn2            25690112
# layer2_0_downsample_0   822083584
# layer2_0_downsample_1   25690112
# add_2                   25690112
# layer2_0_relu_1         25690112
# layer2_1_conv1          14797504512
# layer2_1_bn1            25690112
# layer2_1_relu           25690112
# layer2_1_conv2          14797504512
# layer2_1_bn2            25690112
# add_3                   25690112
# layer2_1_relu_1         25690112
# layer3_0_conv1          7398752256
# layer3_0_bn1            12845056
# layer3_0_relu           12845056
# layer3_0_conv2          14797504512
# layer3_0_bn2            12845056
# layer3_0_downsample_0   822083584
# layer3_0_downsample_1   12845056
# add_4                   12845056
# layer3_0_relu_1         12845056
# layer3_1_conv1          14797504512
# layer3_1_bn1            12845056
# layer3_1_relu           12845056
# layer3_1_conv2          14797504512
# layer3_1_bn2            12845056
# add_5                   12845056
# layer3_1_relu_1         12845056
# layer4_0_conv1          7398752256
# layer4_0_bn1            6422528
# layer4_0_relu           6422528
# layer4_0_conv2          14797504512
# layer4_0_bn2            6422528
# layer4_0_downsample_0   822083584
# layer4_0_downsample_1   6422528
# add_6                   6422528
# layer4_0_relu_1         6422528
# layer4_1_conv1          14797504512
# layer4_1_bn1            6422528
# layer4_1_relu           6422528
# layer4_1_conv2          14797504512
# layer4_1_bn2            6422528
# add_7                   6422528
# layer4_1_relu_1         6422528
# avgpool                 3211264
# fc                      65537000
# ---------------------   -----------
# Input size: (128, 3, 224, 224)
# 233,829,499,880 FLOPs or approx. 233.83 GFLOPs
# (233829499880,
#  [['conv1', 15105785856],
#   ['bn1', 205520896],
#   ['relu', 205520896],
#   ['maxpool', 205520896],
#   ['layer1_0_conv1', 14797504512],
#   ['layer1_0_bn1', 51380224],
#   ['layer1_0_relu', 51380224],
#   ['layer1_0_conv2', 14797504512],
#   ['layer1_0_bn2', 51380224],
#   ['add', 51380224],
#   ['layer1_0_relu_1', 51380224],
#   ['layer1_1_conv1', 14797504512],
#   ['layer1_1_bn1', 51380224],
#   ['layer1_1_relu', 51380224],
#   ['layer1_1_conv2', 14797504512],
#   ['layer1_1_bn2', 51380224],
#   ['add_1', 51380224],
#   ['layer1_1_relu_1', 51380224],
#   ['layer2_0_conv1', 7398752256],
#   ['layer2_0_bn1', 25690112],
#   ['layer2_0_relu', 25690112],
#   ['layer2_0_conv2', 14797504512],
#   ['layer2_0_bn2', 25690112],
#   ['layer2_0_downsample_0', 822083584],
#   ['layer2_0_downsample_1', 25690112],
#   ['add_2', 25690112],
#   ['layer2_0_relu_1', 25690112],
#   ['layer2_1_conv1', 14797504512],
#   ['layer2_1_bn1', 25690112],
#   ['layer2_1_relu', 25690112],
#   ['layer2_1_conv2', 14797504512],
#   ['layer2_1_bn2', 25690112],
#   ['add_3', 25690112],
#   ['layer2_1_relu_1', 25690112],
#   ['layer3_0_conv1', 7398752256],
#   ['layer3_0_bn1', 12845056],
#   ['layer3_0_relu', 12845056],
#   ['layer3_0_conv2', 14797504512],
#   ['layer3_0_bn2', 12845056],
#   ['layer3_0_downsample_0', 822083584],
#   ['layer3_0_downsample_1', 12845056],
#   ['add_4', 12845056],
#   ['layer3_0_relu_1', 12845056],
#   ['layer3_1_conv1', 14797504512],
#   ['layer3_1_bn1', 12845056],
#   ['layer3_1_relu', 12845056],
#   ['layer3_1_conv2', 14797504512],
#   ['layer3_1_bn2', 12845056],
#   ['add_5', 12845056],
#   ['layer3_1_relu_1', 12845056],
#   ['layer4_0_conv1', 7398752256],
#   ['layer4_0_bn1', 6422528],
#   ['layer4_0_relu', 6422528],
#   ['layer4_0_conv2', 14797504512],
#   ['layer4_0_bn2', 6422528],
#   ['layer4_0_downsample_0', 822083584],
#   ['layer4_0_downsample_1', 6422528],
#   ['add_6', 6422528],
#   ['layer4_0_relu_1', 6422528],
#   ['layer4_1_conv1', 14797504512],
#   ['layer4_1_bn1', 6422528],
#   ['layer4_1_relu', 6422528],
#   ['layer4_1_conv2', 14797504512],
#   ['layer4_1_bn2', 6422528],
#   ['add_7', 6422528],
#   ['layer4_1_relu_1', 6422528],
#   ['avgpool', 3211264],
#   ['fc', 65537000]])
